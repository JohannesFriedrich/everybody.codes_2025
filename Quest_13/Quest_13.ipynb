# %% [markdown]
# # Part 1

# %%
file_name = "everybody_codes_e2025_q13_p1.txt"
file = open(file_name, "r")
data = file.read().strip().split("\n")
  
data = [1]+ [int(i) for i in data]

l = [None] * len(data)
l[0] = 1

for i in range(1, len(data)):
    pos = (i +1)//2
    if i%2 == 0:
        l[-pos] = data[i]
    else:
        l[pos] = data[i]

l[2025 % len(data)]
# Out:
# 689

# %% [markdown]
# # Part 2

# %%
file_name = "everybody_codes_e2025_q13_p2.txt"
file = open(file_name, "r")
data = file.read().strip().split("\n")

data = [[1]] + [[k for k in range(int(j[0]),int(j[1])+1)] for j in [i.split("-") for i in data]]

l = [None] * len(data)
l[0] = [1]

for i in range(1, len(data)):
    pos = (i +1)//2
    if i%2 == 0:
        t = data[i]
        l[-pos] = list(reversed(data[i]))
    else:
        l[pos] = data[i]

sorted = [x for xs in l for x in xs]
sorted[20252025 % len(sorted)]
# Out:
# 9705

# %% [markdown]
# # Part 3

# %%
file_name = "everybody_codes_e2025_q13_p3.txt"
file = open(file_name, "r")
data = file.read().strip().split("\n")

# data = 
data = [[1]] + [[k for k in range(int(j[0]),int(j[1])+1)] for j in [i.split("-") for i in data]]

l = [None] * len(data)
l[0] = [1]

for i in range(1, len(data)):
    pos = (i +1)//2
    if i%2 == 0:
        t = data[i]
        l[-pos] = list(reversed(data[i]))
    else:
        l[pos] = data[i]

sorted = [x for xs in l for x in xs]
sorted[202520252025 % len(sorted)]
# Out:
# 449678
